# %% [markdown]
# url = 'https://news.daum.net'
# (1) 섹션 & 링크
# (2) topic / url / section
# (3) sub 페이지 (기사 내용)
#     - 언론사명, 제목, 날짜/시간, 기사 내용, 작성자

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"
from urllib.request import urlopen
import bs4
import pandas as pd
import requests

# %%
url = 'https://news.daum.net'
html = urlopen(url)
# 파서 객체 생성
bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
ul = bs_obj.find('ul',{'class':'gnb_comm'})
lis = ul.findAll('li')

# %%
section = []
link = []

for li in lis:
    a_tag = li.find('a')
    section.append(a_tag.text)
    link.append(url + a_tag['href'])

section_menu_df = pd.DataFrame({'section':section, 'link':link})
section_menu_df
# Out:
#   section                                               link
# 0       홈                             https://news.daum.net/
# 1      사회                      https://news.daum.net/society
# 2      정치                     https://news.daum.net/politics
# 3      경제                     https://news.daum.net/economic
# 4      국제                      https://news.daum.net/foreign
# 5      문화                      https://news.daum.net/culture
# 6      IT                      https://news.daum.net/digital
# 7      연재                      https://news.daum.net/series/
# 8      포토                        https://news.daum.net/photo
# 9    팩트체크  https://news.daum.nethttps://focus.daum.net/ch...

# %% [markdown]
# ### (2) 섹션별 헤드라인(topic) 제목과 url 추출

# %%
def get_topic(url, section):
    # 접속 및 결과 파싱
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36'}
    res = requests.get(url, headers=headers)
    html = res.text
    bs_obj = bs4.BeautifulSoup(html, 'html.parser')

    # topic_list 추출
    topic_list = bs_obj.findAll('div',{'class':'cont_thumb'})

    # 제목과 링크 추출해서 리스트에 추가
    topic_title = []
    topic_link = []

    for topic in topic_list:
        try :
            a = topic.find('a')
            topic_title.append(a.text)
            topic_link.append(a['href'])
        except:
            print('오류 발생')
            # pass
            
    # 딕셔너리 만들어서 반환
    return ({'topic':topic_title, 'url':topic_link, 'section':section})

# %%
# 모든 섹션에 대한 모든 topic 데이터 프레임 생성
all_topic_df = pd.DataFrame({
    'topic':[],
    'url':[],
    'section':[]
})

for i in range(1, 7):
    df = pd.DataFrame(get_topic(section_menu_df['link'][i], section_menu_df['section'][i]))
    all_topic_df = pd.concat([all_topic_df, df], axis=0, ignore_index=True)
    # axis=0 : 행으로 결합
    # ignore_index=True : 기존 df의 인덱스 무시 (모든 행을 새로운 인덱스로 설정)

all_topic_df
# Out:
# 오류 발생
# 오류 발생
# 오류 발생
# 오류 발생
# 오류 발생
# 오류 발생
# 오류 발생
# 오류 발생
#                                                 topic  \
# 0                "후원 취소" 여론에 세이브더칠드 '유감'…교사 향한 사과는 없어
# 1           경윤호 캠코 감사 "국제금융중심지 부산, 패러다임 변화·정책적 육성 필요"
# 2   ‘넷플릭스 강제 결제’, ‘프로필 사진 도용’…미완의 스토킹법, 온라인 스토킹 못 막는다
# 3   “서울로 출퇴근하는 사람이 몇인데”…‘경기·인천 제외’ 서울 교통패스에 시민들 ‘갸우뚱’
# 4                "심폐소생술 교육 진심 참여했죠"…쓰러진 식당 손님 살린 女공무원
# ..                                                ...
# 85                                           STO 발전방향
# 86                                  〈35〉하와이와 IT기업 이야기
# 87                                             거대언어모델
# 88                   액체 수소 연료전지 비행기…미래 친환경 항공기 대세 될까?
# 89                       챗GPT는 '기사 쓰기'를 얼마나 대체할 수 있을까
#
#                                        url section
# 0   https://v.daum.net/v/20230913152418581      사회
# 1   https://v.daum.net/v/20230913152319535      사회
# 2   https://v.daum.net/v/20230913152250509      사회
# 3   https://v.daum.net/v/20230913152110448      사회
# 4   https://v.daum.net/v/20230913152111449      사회
# ..                                     ...     ...
# 85  https://v.daum.net/v/20230912160104428      IT
# 86  https://v.daum.net/v/20230912153058742      IT
# 87  https://v.daum.net/v/20230912141501206      IT
# 88  https://v.daum.net/v/20230912115007130      IT
# 89  https://v.daum.net/v/20230912112348801      IT
#
# [90 rows x 3 columns]

# %% [markdown]
# #### (3) 섹션 헤드라인별 sub 페이지 기사 내용 추출
# 언론사, 제목, 날짜/시간, 기사내용, 작성자

# %%
# sub 페이지 기사 내용 추출하는 함수
def get_sub_news_info(url):
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36'}
    # 빈 리스트 생성
    paper_list, title_list, datetime_list, writing_list, writer_list = [[] for _ in range(5)]
    # for _ in range(5) : 언더바(_) *변수 없이 반복만 수행)
    try :
        res = requests.get(url, headers=headers)
        html = res.text
        bs_obj = bs4.BeautifulSoup(html, 'html.parser')

        # 언론사, 기사제목, 작성 날짜 시간, 기사 내용, 작성자 리스트 생성
        paper_list.append(bs_obj.select_one('#kakaoServiceLogo').text)
        title_list.append(bs_obj.find('h3', {'class' : 'tit_view'}).text)
        datetime_list.append(bs_obj.find('span', {'class' : 'num_date'}).text)
        writing_list.append(bs_obj.find('div', {'class' : 'article_view'}).text.replace('\n', ''))
        writer_list.append(bs_obj.find('span',{'class':'txt_info'}).text)
        
    except:
        print('오류 발생')
        pass


    # 딕셔너리로 만들어서 반환
    sub_news_dict = {
        'paper':paper_list,
        'title':title_list,
        'datetime':datetime_list,
        'writing':writing_list,
        'writer':writer_list
        
    }
    return sub_news_dict

# %%
all_sub_news_info_df = pd.DataFrame({
    'paper': [],
    'title': [],
    'datetime': [],
    'writing': [],
    'writer': []
})

for url in all_topic_df['url']:
    df = pd.DataFrame(get_sub_news_info(url))
    all_sub_news_info_df = pd.concat([all_sub_news_info_df, df], axis=0, ignore_index=True)

all_sub_news_info_df
# Out:
#      paper                                              title  \
# 0      뉴시스               "후원 취소" 여론에 세이브더칠드 '유감'…교사 향한 사과는 없어
# 1      뉴스1          경윤호 캠코 감사 "국제금융중심지 부산, 패러다임 변화·정책적 육성 필요"
# 2    헤럴드경제  ‘넷플릭스 강제 결제’, ‘프로필 사진 도용’…미완의 스토킹법, 온라인 스토킹 못 막는다
# 3     경향신문  “서울로 출퇴근하는 사람이 몇인데”…‘경기·인천 제외’ 서울 교통패스에 시민들 ‘갸우뚱’
# 4      뉴스1               "심폐소생술 교육 진심 참여했죠"…쓰러진 식당 손님 살린 女공무원
# ..     ...                                                ...
# 85    전자신문                                 [블록체인 칼럼] STO 발전방향
# 86    전자신문                    [김장현의 테크와 사람] 〈35〉하와이와 IT기업 이야기
# 87    전자신문                             [ICT 시사용어] 거대언어모델(LLM)
# 88    서울신문     액체 수소 연료전지 비행기…미래 친환경 항공기 대세 될까? [고든 정의 TECH+]
# 89  지디넷코리아                       챗GPT는 '기사 쓰기'를 얼마나 대체할 수 있을까
#
#               datetime                                            writing  \
# 0   2023. 9. 13. 15:24              악성 민원에 시달리다 극단적 선택을 한 대전의 한 초등 교사에...
# 1   2023. 9. 13. 15:23              한국자산관리공사(캠코) 경윤호 감사. ⓒ 뉴스1 부산경남 ...
# 2   2023. 9. 13. 15:22              서울 지하철 6호선 신당역 인근에 마련된 ‘신당역 스토킹 살인...
# 3   2023. 9. 13. 15:21              지난 11일 서울역 환승센터에서 시민들이 버스를 기다리고 있다...
# 4   2023. 9. 13. 15:21              심폐소생술로 의식을 잃고 쓰러진 주민의 소중한 생명을 지켜낸 ...
# ..                 ...                                                ...
# 85  2023. 9. 12. 16:01              김선미 동국대 교수           현재 STO를 통한 블록...
# 86  2023. 9. 12. 15:30              김장현 성균관대 교수           흔히 하와이하면 휴양과...
# 87  2023. 9. 12. 14:15              SK텔레콤 AI 서비스 에이닷용 슈퍼컴퓨터 '타이탄'     ...
# 88  2023. 9. 12. 11:50  [서울신문 나우뉴스]            사진=H2Fly           갈수록 ...
# 89  2023. 9. 12. 11:23  (지디넷코리아=김익현 미디어연구소장)챗GPT를 비롯한 생성 인공지능(AI)이 세상을...
#
#                    writer
# 0               이주영 인턴 기자
# 1                  이현동 기자
# 2   입력 2023. 9. 13. 15:22
# 3                  김세훈 기자
# 4                  엄기찬 기자
# ..                    ...
# 85                    길재식
# 86  입력 2023. 9. 12. 15:30
# 87                    박정은
# 88  입력 2023. 9. 12. 11:50
# 89            김익현 미디어연구소장
#
# [90 rows x 5 columns]

# %%
# 최종 결과 파일로 저장
all_sub_news_info_df.to_csv('./crawl_data/daum_sub_news_section.csv', index=0)

all_sub_news_info_df = pd.read_csv('./crawl_data/daum_sub_news_section.csv')
all_sub_news_info_df
# Out:
#      paper                                              title  \
# 0      뉴시스               "후원 취소" 여론에 세이브더칠드 '유감'…교사 향한 사과는 없어
# 1      뉴스1          경윤호 캠코 감사 "국제금융중심지 부산, 패러다임 변화·정책적 육성 필요"
# 2    헤럴드경제  ‘넷플릭스 강제 결제’, ‘프로필 사진 도용’…미완의 스토킹법, 온라인 스토킹 못 막는다
# 3     경향신문  “서울로 출퇴근하는 사람이 몇인데”…‘경기·인천 제외’ 서울 교통패스에 시민들 ‘갸우뚱’
# 4      뉴스1               "심폐소생술 교육 진심 참여했죠"…쓰러진 식당 손님 살린 女공무원
# ..     ...                                                ...
# 85    전자신문                                 [블록체인 칼럼] STO 발전방향
# 86    전자신문                    [김장현의 테크와 사람] 〈35〉하와이와 IT기업 이야기
# 87    전자신문                             [ICT 시사용어] 거대언어모델(LLM)
# 88    서울신문     액체 수소 연료전지 비행기…미래 친환경 항공기 대세 될까? [고든 정의 TECH+]
# 89  지디넷코리아                       챗GPT는 '기사 쓰기'를 얼마나 대체할 수 있을까
#
#               datetime                                            writing  \
# 0   2023. 9. 13. 15:24              악성 민원에 시달리다 극단적 선택을 한 대전의 한 초등 교사에...
# 1   2023. 9. 13. 15:23              한국자산관리공사(캠코) 경윤호 감사. ⓒ 뉴스1 부산경남 ...
# 2   2023. 9. 13. 15:22              서울 지하철 6호선 신당역 인근에 마련된 ‘신당역 스토킹 살인...
# 3   2023. 9. 13. 15:21              지난 11일 서울역 환승센터에서 시민들이 버스를 기다리고 있다...
# 4   2023. 9. 13. 15:21              심폐소생술로 의식을 잃고 쓰러진 주민의 소중한 생명을 지켜낸 ...
# ..                 ...                                                ...
# 85  2023. 9. 12. 16:01              김선미 동국대 교수           현재 STO를 통한 블록...
# 86  2023. 9. 12. 15:30              김장현 성균관대 교수           흔히 하와이하면 휴양과...
# 87  2023. 9. 12. 14:15              SK텔레콤 AI 서비스 에이닷용 슈퍼컴퓨터 '타이탄'     ...
# 88  2023. 9. 12. 11:50  [서울신문 나우뉴스]            사진=H2Fly           갈수록 ...
# 89  2023. 9. 12. 11:23  (지디넷코리아=김익현 미디어연구소장)챗GPT를 비롯한 생성 인공지능(AI)이 세상을...
#
#                    writer
# 0               이주영 인턴 기자
# 1                  이현동 기자
# 2   입력 2023. 9. 13. 15:22
# 3                  김세훈 기자
# 4                  엄기찬 기자
# ..                    ...
# 85                    길재식
# 86  입력 2023. 9. 12. 15:30
# 87                    박정은
# 88  입력 2023. 9. 12. 11:50
# 89            김익현 미디어연구소장
#
# [90 rows x 5 columns]
